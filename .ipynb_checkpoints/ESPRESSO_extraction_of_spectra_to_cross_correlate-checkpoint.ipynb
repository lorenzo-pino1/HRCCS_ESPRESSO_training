# %% [markdown]
# **Goal of this workshop**:
#
# Get acquainted with reduction of optical data, with a particular focus on ESPRESSO and on the differences with nIR data. The following notebook is fully functional, provided that you have: (1) python 3 and some very common packages that can be installed with anaconda; (2) some ESPRESSO data already processed through the ESO pipelines.
#
# For the latter, I give you all the steps that you can apply yourself to any set of public or proprietary data to which you have access. This is a very disk space and time consuming process, thus I do not provide the reduced data here.
#
# You will get this notebook and, on request and on collaborative basis, the full pipeline that I am writing for this reduction. This is a highly modular pipeline (to complement it with stuff like PCA and other methods) and compatible with ESPRESSO, HARPS-N and MAROON-X. I plan to make it public, it is currently in development but is already functional (with this same code, I have published my Pino et al., 2020 paper).
#
# Write me to lorenzo.pino@inaf.it if interested!!!

# %% [markdown]
# # Data format and preparation

# %% [markdown]
# ## ESO pipelines

# %% [markdown]
# Unlike with MAROON-X, we do not have an efficient team of people giving us the data in a usable form. We have to prepare our own data, using ESO pipelines.
#
# ESO pipelines are a bit messy to install, but the ESO support team is very responsive and will help you in the process. I managed to install the pipelines on a Mac relatively effortlessly.
#
# ESO pipelines are called "recipes", and can be run in different environments. Esorex is a command line tool. However, there is a convenient API called Esoreflex, which wraps Esorex in a more immediate form. This is what I use for the ESPRESSO pipelines.
#
# From the README: Data reduction is demanding in terms of system resources. The user should have at least 16 GB of RAM, and 1 TB of free disk space. Better is to have 32 GB of RAM and 4 TB of free disk space. Please note that only the demo requires 30 GB of free space to be installed and generates additional 10 GB of products. This sets also minimum root directory space requirements for RPM installation. Data reduction for SINGLE modes (in particular not binned data) is slow, and may take 45 min. As some recipes parallelise code using OpenMP, data reduction is faster on multi-core systems.
#
# ... Yes, it is kind of a nightmare.
#
# Create a folder tree:
# ESPRESSO_observations/<Run_name>/data_with_raw_calibs
# ESPRESSO_observations/<Run_name>/reflex_end_products
#
# We will have two runs: WASP-76b_transmission_run_1; WASP-76b_transmission_run_2

# %% [markdown]
# ## Data download

# %% [markdown]
# For this tutorial, we will use the data published in Ehrenreich et al. (2021). Step 0 is to get the data from the ESO archive.
#
# There is a user friendly version of the archive (science portal) that contains pre-reduced spectra. These are good for a quick look, but not for science. So, we instead use the raw data portal (http://archive.eso.org/eso/eso_archive_main.html)
#
# Let's search for WASP-76b, and select the ESPRESSO instrument. To make sure you do not lose any data, click on the Program ID. Ehrenreich et al. uses two runs, both public: 1102.C-0744(C) and 1102.C-0744(D). In the window that opens, click on "FileList". That gives you a list of all science exposures in that run. We "Mark all", and "Request marked datasets (new service)".
#
# We will not just need the science exposures, but also the calibrations, in order to run the pipeline. So let's "run association" of the **raw** calibrations (not processed). After the associatiton is done (it takes a while), we can download everything. I recommend the shell script.
#
# Place the script for each run in the "data_with_raw_calibs", change permissions if needed (chmod u+x <script_name>) and run. You are downloading about 10 GB of data, so it may take a while. After everything is done, unzip the archives.
#
# You should have lots of fits files. Most of them are calibrations, and may contain a date that does not coincide with the observational night. The observations have an associated raw2raw.xml, which associates the calibrations to the exposure. If some files are missing, repeat the process.

# %% [markdown]
# ## Using esoreflex

# %% [markdown]
# You will need a configuration file of type ".kar". If you installed your ESO pipelines, you'll have an example to follow. In this drive (https://drive.google.com/drive/u/2/folders/1Xfu2wWyn8WO1DgOQsYmxj8gBMTMWUJ-W) I placed the one that I used for the tutorial.
#
# 1) Change the RAW_DATA_DIR and END-PRODUCTS-DIR according to your tree;
# 2) Tools -> Animate at Runtime -> 10
#
# Launch!
#
# Esoreflex requires some interaction. First, it will read the files, and present you with boxes to tick to select the files you'd like to reduce. If they are greyd out, it means that it could not find the calibrations. Go back to previous steps, and/or check your directory tree.
#
# In the first pop-up window, have a look at the extracted spectra using the mask. If this is satisfactory, click the option "Use the parameters above as initial values in the subsequent executions of this receipe". In this way you'll have no more pop-ups, and esoreflex will run on its own.
#
# You can also interrupt the execution of the pipeline and resume at a different moment. Esoreflex knows which files you have reduced or not, and by default it should not overwrite them. If you wish to overwrite, find the "lazy mode" and disable it (so Esoreflex will actually do everything from the beginning

# %% [markdown]
# ## Output of esoreflex

# %% [markdown]
# In the output folder, esoreflex creates a folder with the date and time on which the workflow was called. So if you do parts of the analysis on different times, you will have the results under different folders. Within this folder you will find one subfolder for each exposure, which contains the final products. Only some of them are useful for us.
#
# ESPRESSO has two fibers. Fiber A contains the spectra of the planet, and fiber B can be placed on different sources depending on the observer's choice. Usually, it is placed on sky, to monitor telluric emission.
#
# **<OB_name>_S2D_BLAZE_A_<Esposure_UT_time>**: gives the blaze function in fiber A.
#
# **<OB_name>_S2D_SKYSUB_A_<Esposure_UT_time>**: gives the 2-dimensional spectra from fiber A, after subtracting fiber B. This is necessary to remove the telluric emission lines, but it could in some cases introduce extra noise. This is what I am currently using and is suggested, but you may explore the impact of avoiding the sky subtrction.
#
# In addition, there are many other files, for both fiber A and B. For example, there are flux calibrated spectra (currently, Feb 2022, ESPRESSO flux calibration is not completely reliable, and not accurate enough to recover the flux at the precision needed for exoplanet atmosphere applications). Finally, there are CCFs calculated by the pipeline with an algorithm which is very similar to the one I give you (but much slower!).
#
# From here on, we are on our own and we can start the data reduction.

# %% [markdown]
# # Data reduction

# %% [markdown]
# Compared to nIR data, optical data can be seen as "easier", in the sense that we have less telluric contamination. We have more contamination from the star, but if this is well behaved it is relatively simple to correct for (but this depends on application).
#
# I thus provide you with a very simple data reduction pipeline, which *does not correct for tellurics*, and is already sufficient to reproduce results from the literature (e.g., Ehrenreich et al., 2021; Pino et al., 2020). Of course, this can be improved.

# %% [markdown]
# ## Reading and preparing data

# %% [markdown]
# These are the operations we need to perform:
#
# 1) Read data;
#
# 2) Apply color correction;
#
# 3) Move the stellar rest frame to remove stellar lines;
#
# 4) Additional flattening and filtering of outliers.

# %% [markdown]
# First, we import libraries, and open the fits files. Some tidying now will spare headaches later!

# %% [markdown]
# ### Reading

# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib
from astropy import visualization

# %%
# Working with fits files. Works with different kinds of inputs (SKYSUB or not etc).

def read_sorted_hdus(input_data_directory, data_type, target_name):
    
    # Get all data in folder of the specified type
    import glob
    data_files = np.array(glob.glob(input_data_directory + '*_{}_*'.format(data_type)))
    
    # Read date and time from the filename (standardized)
    date_time_observations = get_date_time_observations(data_files, data_type=data_type)
    
    # Sort exposures in time
    time_sorted_exposures_mask = compute_time_sorted_exposures_mask(date_time_observations)
    data_files_sorted = data_files[time_sorted_exposures_mask]

    # Open the fits and return them. Not the cheapest in terms of memory, but we'll use some of the info in the headers
    hdus = []
    for file_name in data_files_sorted:
        hdu = fits.open(file_name)
        if hdu[0].header['HIERARCH ESO OBS TARG NAME'] == target_name:
            hdus.append(hdu)    

    return hdus

def get_date_time_observations(data_files, data_type):
    """ Extract the date and time of an expsure from its name.
    """
    import re
    re.compile(data_type)

    date_time_observations = [] 

    for file in data_files:
        start = re.search(data_type + '_', file).end()

        date = file[start:start+10]
        time = file[start+11:start+23]

        date_time_observations.append([date, time])

    return date_time_observations

def compute_time_sorted_exposures_mask(date_time_observations):
    """ From strings to datetime objects
    """

    date_time_observations_datetime=[]
    from datetime import datetime
    for dt in date_time_observations:
        date_time_observations_datetime.append(datetime.strptime(dt[0] + ' ' + dt[1][:-4], "%Y-%m-%d %H:%M:%S"))    

    return np.argsort(date_time_observations_datetime)

# %%
input_data_directory = '/data2/pino/Data/observations/ESPRESSO/W76b_2018_10_31/'
data_type='S2D_SKYSUB_A'
target_name='BD+01   316' # From the header of ESPRESSO files

# Read the sorted hdus
hdus_S2D = read_sorted_hdus(input_data_directory = input_data_directory, data_type=data_type, target_name=target_name)

len(hdus_S2D)
# Out:
# 70

# %%
hdus_S2D[0][0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2022-02-10T19:56:13' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'ESO-PARANAL'        / European Southern Observatory
# TELESCOP= 'ESO-VLT-U3'         / ESO <TEL>
# INSTRUME= 'ESPRESSO'           / Instrument used.
# OBJECT  = 'BD+01   316'        / Original target.
# RA      =            26.632707 / [deg] 01:46:31.8 RA (J2000) pointing
# DEC     =              2.70078 / [deg] 02:42:02.8 DEC (J2000) pointing
# EQUINOX =                2000. / Standard FK5
# RADECSYS= 'FK5     '           / Coordinate system
# EXPTIME =                 300. / Integration time
# MJD-OBS =       58422.04992433 / Obs start
# DATE-OBS= '2018-10-31T01:11:53.461' / Observing date
# UTC     =                4301. / [s] 01:11:41.000 UTC
# LST     =            83234.812 / [s] 23:07:14.812 LST
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# ARCFILE = 'ESPRE.2018-10-31T01:11:53.462.fits' / Archive File Name
# DATAMD5 = 'd4342768090822fb3a76e8b4a487678f' / MD5 checksum
# PIPEFILE= 'ESPRESSO_S2D_SKYSUB_A.fits' / Filename of data product
# HIERARCH ESO OBS AIRM =    2.8 / Req. max. airmass
# HIERARCH ESO OBS AMBI FWHM = 2. / Req. max. seeing
# HIERARCH ESO OBS AMBI TRANS = '3THN    ' / Req. sky transparency
# HIERARCH ESO OBS ATM = 'NATM    ' / Req. Atmospheric Turbulence Model
# HIERARCH ESO OBS CONTAINER ID = 2056357 / Scheduling container ID
# HIERARCH ESO OBS CONTAINER TYPE = 'U       ' / Scheduling container type
# HIERARCH ESO OBS CONTRAST = 0. / Req. contrast
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-2.0' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 40990 / Expected execution time
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS ID =  2191743 / Observation block ID
# HIERARCH ESO OBS MOON DIST = 30 / Req. min. angular dist. from moon [deg]
# HIERARCH ESO OBS MOON FLI = 1. / Req. max. fractional lunar illum.
# HIERARCH ESO OBS NAME = 'WASP-76b' / OB name
# HIERARCH ESO OBS NTPL =      2 / Number of templates within OB
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 53322 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '1102.C-0744(D)' / ESO program identification
# HIERARCH ESO OBS START = '2018-10-31T01:08:03' / OB start time
# HIERARCH ESO OBS STREHLRATIO = 0. / Req. strehl ratio
# HIERARCH ESO OBS TARG NAME = 'BD+01   316' / OB target name
# HIERARCH ESO OBS TPLNO =     2 / Template number within OB
# HIERARCH ESO OBS TWILIGHT =  0 / Req. twilight
# HIERARCH ESO OBS WATERVAPOUR = 30. / Req. water vapour
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO =     1 / Exposure number within template
# HIERARCH ESO TPL ID = 'ESPRESSO_singleHR_obs' / Template signature ID
# HIERARCH ESO TPL NAME = 'ESPRESSO_singleHR_obs' / Template name
# HIERARCH ESO TPL NEXP =    110 / Number of exposures within template
# HIERARCH ESO TPL PRESEQ = 'ESPRESSO_obs.seq' / Sequencer script
# HIERARCH ESO TPL START = '2018-10-31T01:11:20' / TPL start time
# HIERARCH ESO TPL VERSION = '$Revision: 315327 $' / Version of the template
# HIERARCH ESO TEL3 AIRM END = 1.449 / Airmass at end
# HIERARCH ESO TEL3 AIRM START = 1.481 / Airmass at start
# HIERARCH ESO TEL3 ALT = 42.431 / [deg] Alt angle at start
# HIERARCH ESO TEL3 AMBI FWHM END = 0.74 / [arcsec] Observatory Seeing queried fro
# HIERARCH ESO TEL3 AMBI FWHM START = 0.72 / [arcsec] Observatory Seeing queried f
# HIERARCH ESO TEL3 AMBI IRSKY TEMP = -94.6 / Temperature of the IR sky, from radi
# HIERARCH ESO TEL3 AMBI IWV END = 1.56 / Integrated Water Vapor
# HIERARCH ESO TEL3 AMBI IWV START = 1.58 / Integrated Water Vapor
# HIERARCH ESO TEL3 AMBI IWV30D END = 1.72 / IWV at 30deg elev.
# HIERARCH ESO TEL3 AMBI IWV30D START = 1.74 / IWV at 30deg elev.
# HIERARCH ESO TEL3 AMBI IWV30DSTD END = 0.03 / IWV at 30deg elev.
# HIERARCH ESO TEL3 AMBI IWV30DSTD START = 0.03 / IWV at 30deg elev.
# HIERARCH ESO TEL3 AMBI IWVSTD END = 0.03 / Standard Deviation of Integrated Wate
# HIERARCH ESO TEL3 AMBI IWVSTD START = 0.04 / Standard Deviation of Integrated Wa
# HIERARCH ESO TEL3 AMBI PRES END = 745.5 / [hPa] Observatory ambient air pressur
# HIERARCH ESO TEL3 AMBI PRES START = 745.5 / [hPa] Observatory ambient air press
# HIERARCH ESO TEL3 AMBI RHUM = 3. / [%] Observatory ambient relative humidity qu
# HIERARCH ESO TEL3 AMBI TAU0 = 0.0049 / [s] Average coherence time
# HIERARCH ESO TEL3 AMBI TEMP = 15.71 / [deg C] Observatory ambient temperature qu
# HIERARCH ESO TEL3 AMBI WINDDIR = 181.5 / [deg] Observatory ambient wind directio
# HIERARCH ESO TEL3 AMBI WINDSP = 2.73 / [m/s] Observatory ambient wind speed quer
# HIERARCH ESO TEL3 AZ = 240.561 / [deg] Az angle at start S=0,W=90
# HIERARCH ESO TEL3 CHOP ST =  F / True when chopping is active
# HIERARCH ESO TEL3 DATE = '2000-01-01T00:00:00' / TCS installation date
# HIERARCH ESO TEL3 DID = 'ESO-VLT-DIC.TCS' / Data dictionary for TELi
# HIERARCH ESO TEL3 DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL3 FO POS =  0. / Adapter focus position during tracking
# HIERARCH ESO TEL3 FOCU ID = 'NB      ' / Telescope focus station ID
# HIERARCH ESO TEL3 FOCU LEN = 120. / [m] Focal length
# HIERARCH ESO TEL3 FOCU SCALE = 1.718 / [arcsec/mm] Focal scale
# HIERARCH ESO TEL3 FOCU VALUE = -31.566 / [mm] M2 setting
# HIERARCH ESO TEL3 GEOELEV = 2648. / [m] Elevation above sea level
# HIERARCH ESO TEL3 GEOLAT = -24.6268 / [deg] Tel geo latitute (+=North)
# HIERARCH ESO TEL3 GEOLON = -70.4045 / [deg] Tel geo longitude (+=East)
# HIERARCH ESO TEL3 IA FWHM = 0.95 / [arcsec] Delivered seeing corrected by airmas
# HIERARCH ESO TEL3 IA FWHMLIN = 1.06 / Delivered seeing on IA detector (linear fi
# HIERARCH ESO TEL3 IA FWHMLINOBS = 1.32 / Delivered seeing on IA detector (linear
# HIERARCH ESO TEL3 ID = 'v 313800' / TCS version number
# HIERARCH ESO TEL3 MOON DEC = 20.37157 / [deg] 20:22:17.6 DEC (J2000)
# HIERARCH ESO TEL3 MOON RA = 121.890445 / [deg] 08:07:33.7 RA (J2000)
# HIERARCH ESO TEL3 OPER = 'I, Condor' / Telescope Operator
# HIERARCH ESO TEL3 PARANG END = -128.489 / [deg] Parallactic angle at end
# HIERARCH ESO TEL3 PARANG START = -127.569 / [deg] Parallactic angle at start
# HIERARCH ESO TEL3 TARG ALPHA = 14631.85 / Alpha coordinate for the target
# HIERARCH ESO TEL3 TARG COORDTYPE = 'M       ' / Coordinate type (M=mean A=appare
# HIERARCH ESO TEL3 TARG DELTA = 24202. / Delta coordinate for the target
# HIERARCH ESO TEL3 TARG EPOCH = 2000. / [yr] Epoch 1950 or 2000
# HIERARCH ESO TEL3 TARG EPOCHSYSTEM = 'J       ' / Epoch system (J=Julian / B=Bes
# HIERARCH ESO TEL3 TARG EQUINOX = 2000. / [yr] Equinox
# HIERARCH ESO TEL3 TARG PARALLAX = 0. / [arcsec] Parallax
# HIERARCH ESO TEL3 TARG PMA = 0.0454 / [arcsec/yr] Proper Motion Alpha
# HIERARCH ESO TEL3 TARG PMD = -0.0408 / [arcsec/yr] Proper motion Delta
# HIERARCH ESO TEL3 TARG RADVEL = 0. / [km/s] Radial velocity
# HIERARCH ESO TEL3 TH M1 TEMP = 13.36 / [deg C] M1 superficial temperature
# HIERARCH ESO TEL3 TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO INS DATE = '2012-10-16' / Instrument release date (yyyy-mm-dd).
# HIERARCH ESO INS MODE = 'SINGLEHR' / Instrument mode used.
# HIERARCH ESO INS3 ADC1 DEC = 24738.62966 / [deg] Telescope desclination.
# HIERARCH ESO INS3 ADC1 ENC = 5523 / [Enc] ADC absolute position.
# HIERARCH ESO INS3 ADC1 ID =  0 / ADC unique id
# HIERARCH ESO INS3 ADC1 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS3 ADC1 NAME = 'ADC UT3 wheel 1' / ADC name
# HIERARCH ESO INS3 ADC1 POS = 9.4634 / [deg] Position in user units
# HIERARCH ESO INS3 ADC1 POSANG = 9.4634 / Position angle [deg].
# HIERARCH ESO INS3 ADC1 RA = 14730.55968 / [deg] Telescope right ascension.
# HIERARCH ESO INS3 ADC1 SENS1 = 745.5 / [mbar] Pressure.
# HIERARCH ESO INS3 ADC1 TEMP = 15.6 / [C] Temperature.
# HIERARCH ESO INS3 ADC2 DEC = 24738.62966 / [deg] Telescope desclination.
# HIERARCH ESO INS3 ADC2 ENC = 186947 / [Enc] ADC absolute position.
# HIERARCH ESO INS3 ADC2 ID =  0 / ADC unique id
# HIERARCH ESO INS3 ADC2 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS3 ADC2 NAME = 'ADC UT3 wheel 2' / ADC name
# HIERARCH ESO INS3 ADC2 POS = 320.291265 / [deg] Position in user units
# HIERARCH ESO INS3 ADC2 POSANG = 320.2913 / Position angle [deg].
# HIERARCH ESO INS3 ADC2 RA = 14730.55968 / [deg] Telescope right ascension.
# HIERARCH ESO INS3 ADC2 SENS1 = 745.5 / [mbar] Pressure.
# HIERARCH ESO INS3 ADC2 TEMP = 15.6 / [C] Temperature.
# HIERARCH ESO INS3 CALSEL ENC = 30000 / [Enc] Component absolute position.
# HIERARCH ESO INS3 CALSEL ID = 'TRG_SKY ' / Unique ID.
# HIERARCH ESO INS3 CALSEL NAME = 'TRG_SKY ' / FE Calibration selector.
# HIERARCH ESO INS3 CALSEL NO = 1 / CALSEL slot number.
# HIERARCH ESO INS3 CALSEL POS = 15. / [mm] Component position.
# HIERARCH ESO INS3 CALSEL TYPE = 'MASK    ' / OPTIi element.
# HIERARCH ESO INS3 DID1 = 'ICS3_ICS-296578' / Data dictionary for INS.
# HIERARCH ESO INS3 DID2 = 'PRIMARY-FITS-1.2' / Data dictionary for INS.
# HIERARCH ESO INS3 FILT1 ENC = 39259 / [Enc] FS Filter wheel absolute position.
# HIERARCH ESO INS3 FILT1 ID = 'ND_100-0.50' / FS Filter unique id.
# HIERARCH ESO INS3 FILT1 NAME = 'FSND10  ' / FS Filter name.
# HIERARCH ESO INS3 FILT1 NO = 2 / FS Filter wheel position index.
# HIERARCH ESO INS3 FILT1 POS = 59.9995 / [deg] Component position.
# HIERARCH ESO INS3 FILT1 TYPE = 'FILTER  ' / FS OPTIi element.
# HIERARCH ESO INS3 FOCU ENC = 27999 / [Enc] Absolute position.
# HIERARCH ESO INS3 FOCU ID =  0 / Unique id
# HIERARCH ESO INS3 FOCU NAME = 'Focusing stage UT3' / Name
# HIERARCH ESO INS3 FOCU POS = 14. / [mm] Position.
# HIERARCH ESO INS3 ID = 'ESPRESSO/ICS3' / Instrument ID.
# HIERARCH ESO INS3 PATH = '        ' / Optical path used.
# HIERARCH ESO INS3 SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS3 TILT1 ENG2ARCX = 0.00023 / Conversion factor from engineering
# HIERARCH ESO INS3 TILT1 ENG2ARCY = 0.00015 / Conversion factor from engineering
# HIERARCH ESO INS3 TILT1 ENG2MRADX = 0.0004 / Conversion factor from engineering
# HIERARCH ESO INS3 TILT1 ENG2MRADY = 0.0004 / Conversion factor from engineering
# HIERARCH ESO INS3 TILT1 ID = 'iops3   ' / FS/PS id.
# HIERARCH ESO INS3 TILT1 MODE = 'REF     ' / Device mode.
# HIERARCH ESO INS3 TILT1 NAME = 'I/O Pupil stabil 3' / Device description.
# HIERARCH ESO INS3 TILT1 VAL1 = 14372. / Piezo axis  numeric value.
# HIERARCH ESO INS3 TILT1 VAL2 = 11493. / Piezo axis  numeric value.
# HIERARCH ESO INS3 TILT2 ENG2ARCX = 0.00018 / Conversion factor from engineering
# HIERARCH ESO INS3 TILT2 ENG2ARCY = 0.00012 / Conversion factor from engineering
# HIERARCH ESO INS3 TILT2 ENG2MRADX = 0.0004 / Conversion factor from engineering
# HIERARCH ESO INS3 TILT2 ENG2MRADY = 0.0004 / Conversion factor from engineering
# HIERARCH ESO INS3 TILT2 ID = 'iofs3   ' / FS/PS id.
# HIERARCH ESO INS3 TILT2 MODE = 'AUTO    ' / Device mode.
# HIERARCH ESO INS3 TILT2 NAME = 'I/O Field stabil 3' / Device description.
# HIERARCH ESO INS3 TILT2 VAL1 = 14942. / Piezo axis  numeric value.
# HIERARCH ESO INS3 TILT2 VAL2 = 13707. / Piezo axis  numeric value.
# HIERARCH ESO INS5 DID1 = 'ICS5_ICS-315386' / Data dictionary for INS.
# HIERARCH ESO INS5 DID2 = 'PRIMARY-FITS-1.2' / Data dictionary for INS.
# HIERARCH ESO INS5 FESELA ENC = 69497 / [Enc] Absolute position.
# HIERARCH ESO INS5 FESELA ID = '17      ' / Unique ID.
# HIERARCH ESO INS5 FESELA NAME = 'FE1_FP  ' / Name.
# HIERARCH ESO INS5 FESELA NO = 17 / Slot number.
# HIERARCH ESO INS5 FESELA POS = 34.7485 / [mm] Component position.
# HIERARCH ESO INS5 FESELA TYPE = 'MASK    ' / Element.
# HIERARCH ESO INS5 FESELB ENC = 189232 / [Enc] Absolute position.
# HIERARCH ESO INS5 FESELB ID = '19      ' / Unique ID.
# HIERARCH ESO INS5 FESELB NAME = 'FE3_FP  ' / Name.
# HIERARCH ESO INS5 FESELB NO = 19 / Slot number.
# HIERARCH ESO INS5 FESELB POS = 94.616 / [mm] Component position.
# HIERARCH ESO INS5 FESELB TYPE = 'MASK    ' / Element.
# HIERARCH ESO INS5 FILT2 ENC = 117778 / [Enc] EM Filter wheel absolute position.
# HIERARCH ESO INS5 FILT2 ID = 'ND1_ID  ' / EM Filter unique id.
# HIERARCH ESO INS5 FILT2 NAME = 'EMND00  ' / EM Filter name.
# HIERARCH ESO INS5 FILT2 NO = 1 / EM Filter wheel position index.
# HIERARCH ESO INS5 FILT2 POS = 180. / [deg] Component position.
# HIERARCH ESO INS5 FILT2 TYPE = 'FREE    ' / Element.
# HIERARCH ESO INS5 ID = 'ESPRESSO/ICS5' / Instrument ID.
# HIERARCH ESO INS5 LAMP4 FREQ = 18000000000. / [Hz] Absolute frequency
# HIERARCH ESO INS5 LAMP4 FREQOFFS = 7350000000. / [Hz] Offset of first comb
# HIERARCH ESO INS5 LAMP4 ID = 'LFC1    ' / LFC instance ID
# HIERARCH ESO INS5 LAMP4 LEVEL = -17. / Level
# HIERARCH ESO INS5 LAMP4 NAME = 'LFC red ' / LFC instance name
# HIERARCH ESO INS5 LAMP4 STABLE = F / Light OK since reset
# HIERARCH ESO INS5 LAMP4 STAT = 'OFF     ' / Status of LFC
# HIERARCH ESO INS5 LAMP5 ID = 'FPCS    ' / Lamp ID.
# HIERARCH ESO INS5 LAMP5 NAME = 'FPCS_Lamp' / Lamp name.
# HIERARCH ESO INS5 LAMP5 ST = T / Lamp activated.
# HIERARCH ESO INS5 LAMP5 STAT = 'ON      ' / Lamp activated.
# HIERARCH ESO INS5 LAMP5 TIME = 17745. / Time [sec] lamp was on.
# HIERARCH ESO INS5 LSELA ENC = 152009 / [Enc] Absolute position.
# HIERARCH ESO INS5 LSELA ID = '7       ' / Unique ID.
# HIERARCH ESO INS5 LSELA NAME = 'DARK    ' / Name.
# HIERARCH ESO INS5 LSELA NO = 7 / Slot number.
# HIERARCH ESO INS5 LSELA POS = 76.0045 / [mm] Component position.
# HIERARCH ESO INS5 LSELA TYPE = 'MASK    ' / Element.
# HIERARCH ESO INS5 LSELB ENC = 152007 / [Enc] Absolute position.
# HIERARCH ESO INS5 LSELB ID = '7       ' / Unique ID.
# HIERARCH ESO INS5 LSELB NAME = 'DARK    ' / Name.
# HIERARCH ESO INS5 LSELB NO = 7 / Slot number.
# HIERARCH ESO INS5 LSELB POS = 76.0035 / [mm] Component position.
# HIERARCH ESO INS5 LSELB TYPE = 'MASK    ' / Element.
# HIERARCH ESO INS5 MODSEL ENC = 1677485 / [Enc] Component absolute position.
# HIERARCH ESO INS5 MODSEL ID = 'UT3HR   ' / Unique ID.
# HIERARCH ESO INS5 MODSEL NAME = 'UT3HR   ' / MODSEL name.
# HIERARCH ESO INS5 MODSEL NO = 4 / MODSEL slot number.
# HIERARCH ESO INS5 MODSEL POS = 167.7485 / [deg] Component position.
# HIERARCH ESO INS5 MODSEL TYPE = 'MASK    ' / MODSEL element.
# HIERARCH ESO INS5 PATH = '        ' / Optical path used.
# HIERARCH ESO INS5 PRES100 VAL = 1.573E-05 / [mbar] Blue cryostat pressure.
# HIERARCH ESO INS5 PRES101 VAL = 1.056E-05 / [mbar] Red cryostat pressure.
# HIERARCH ESO INS5 PRES102 VAL = 0. / [mbar] Cryopump1 cryostat pressure.
# HIERARCH ESO INS5 PRES103 VAL = 290.6 / [mbar] Cryopump2 cryostat pressure.
# HIERARCH ESO INS5 PRES104 VAL = 4.415E-06 / [mbar] Manifold vacuum pressure.
# HIERARCH ESO INS5 PRES105 VAL = 888900. / [mbar] Pre vacuum pressure.
# HIERARCH ESO INS5 PRES106 VAL = 2.743E-06 / [mbar] Vessel vacuum pressure.
# HIERARCH ESO INS5 PRES107 VAL = 0.0001154 / [mbar] Fabry-Perot vacuum pressure.
# HIERARCH ESO INS5 SENS1 VAL = 12.8 / [%] VV regulator heater output.
# HIERARCH ESO INS5 SENS101 VAL = 95.492989 / [K] Blue cryostat cold plate temp.
# HIERARCH ESO INS5 SENS109 VAL = 95.302879 / [K] Red cryostat cold plate temp.
# HIERARCH ESO INS5 SENS150 VAL = 65.800003 / [%] Blue detector mount heat.
# HIERARCH ESO INS5 SENS151 VAL = 15.32185 / [%] Blue detector table heater.
# HIERARCH ESO INS5 SENS152 VAL = 67.400002 / [%] Red detector mount heat.
# HIERARCH ESO INS5 SENS153 VAL = 0. / [%] Red detector table heater.
# HIERARCH ESO INS5 SENS154 VAL = 0.000115 / [%] Blue detector front flange heater
# HIERARCH ESO INS5 SENS155 VAL = 0.000115 / [%] Red detector front flange heater.
# HIERARCH ESO INS5 SENS2 VAL = 2.4 / [%] FP regulator heater output.
# HIERARCH ESO INS5 SENSOR1 ID = 'topt    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR1 NAME = 'Optical components (Lake 218)' / Sensor device
# HIERARCH ESO INS5 SENSOR10 ID = 'cab3    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR10 NAME = 'Thermal Cabinet cooling controller' / Sensor
# HIERARCH ESO INS5 SENSOR11 ID = 'dis1    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR11 NAME = 'Digital signals 1' / Sensor device common nam
# HIERARCH ESO INS5 SENSOR12 ID = 'dis2    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR12 NAME = 'Digital signals 2' / Sensor device common nam
# HIERARCH ESO INS5 SENSOR13 ID = 'alpiq   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR13 NAME = '2T enclosure sensors' / Sensor device common
# HIERARCH ESO INS5 SENSOR14 ID = 'tencl   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR14 NAME = 'Housekeeping (Lake 218)' / Sensor device comm
# HIERARCH ESO INS5 SENSOR15 ID = 'cryohf  ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR15 NAME = 'VCS system high-freq samp' / Sensor device co
# HIERARCH ESO INS5 SENSOR16 ID = 'vccc    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR16 NAME = 'Vacuum Cabinet Cooling Controller' / Sensor d
# HIERARCH ESO INS5 SENSOR2 ID = 'tbenc   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR2 NAME = 'Optical bench (Lake 218)' / Sensor device comm
# HIERARCH ESO INS5 SENSOR3 ID = 'tvv     ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR3 NAME = 'Vacuum Vessel (Lake 218)' / Sensor device comm
# HIERARCH ESO INS5 SENSOR4 ID = 'regvv   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR4 NAME = 'Lakeshore 336' / Sensor device common name.
# HIERARCH ESO INS5 SENSOR5 ID = 'reg3T   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR5 NAME = 'Lakeshore 336' / Sensor device common name.
# HIERARCH ESO INS5 SENSOR6 ID = 'cryo    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR6 NAME = 'VCS system' / Sensor device common name.
# HIERARCH ESO INS5 SENSOR7 ID = 'tfe     ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR7 NAME = 'FEs temperature sensors' / Sensor device commo
# HIERARCH ESO INS5 SENSOR8 ID = 'cab1    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR8 NAME = 'Main Cabinet cooling controller' / Sensor devi
# HIERARCH ESO INS5 SENSOR9 ID = 'cab2    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR9 NAME = 'Calibration Cabinet cooling controller' / Sens
# HIERARCH ESO INS5 SHUSEL CFG = 'HR      ' / Device configuration.
# HIERARCH ESO INS5 SHUSEL ID = 'shusel  ' / Unique ID.
# HIERARCH ESO INS5 SHUSEL MODE = 'OPER    ' / Device mode.
# HIERARCH ESO INS5 SHUSEL NAME = 'Shutter selector' / Name.
# HIERARCH ESO INS5 SHUSEL ST = 'CLOSED  ' / Device status.
# HIERARCH ESO INS5 SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS5 TEMP1 VAL = 18.809 / [C] Main collimator.
# HIERARCH ESO INS5 TEMP10 VAL = 18.684 / [C] Near echelle grating.
# HIERARCH ESO INS5 TEMP100 VAL = 96.194992 / [K] Blue cryostat sorption pump temp
# HIERARCH ESO INS5 TEMP101 VAL = 19.003 / [C] Blue front flange temp.
# HIERARCH ESO INS5 TEMP102 VAL = 99.217415 / [K] Red cryostat sorption pump temp.
# HIERARCH ESO INS5 TEMP103 VAL = 19.003 / [C] Red front flange temp.
# HIERARCH ESO INS5 TEMP104 VAL = 0. / [K] Cryopump1 cold plate temp.
# HIERARCH ESO INS5 TEMP105 VAL = 0. / [K] Cryopump1 sorption pump temp.
# HIERARCH ESO INS5 TEMP106 VAL = 0. / [K] Cryopump1 2nd stage temp.
# HIERARCH ESO INS5 TEMP107 VAL = 0. / [K] Cryopump2 cold plate temp.
# HIERARCH ESO INS5 TEMP108 VAL = 0. / [K] Cryopump2 sorption pump temp.
# HIERARCH ESO INS5 TEMP109 VAL = 0. / [K] Cryopump2 2nd stage temp.
# HIERARCH ESO INS5 TEMP11 VAL = 18.542 / [C] Near red camera.
# HIERARCH ESO INS5 TEMP12 VAL = 18.619 / [C] Near blue camera.
# HIERARCH ESO INS5 TEMP13 VAL = 18.607 / [C] Optical bench feet 1.
# HIERARCH ESO INS5 TEMP14 VAL = 18.598 / [C] Optical bench feet 2.
# HIERARCH ESO INS5 TEMP15 VAL = 18.64 / [C] Optical bench feet 3.
# HIERARCH ESO INS5 TEMP150 VAL = 148.003998 / [K] Blue detector mount temp.
# HIERARCH ESO INS5 TEMP151 VAL = 154.968994 / [K] Blue detector package temp.
# HIERARCH ESO INS5 TEMP152 VAL = 146.513702 / [K] Blue detector table temp.
# HIERARCH ESO INS5 TEMP153 VAL = 147.505005 / [K] Red detector mount temp.
# HIERARCH ESO INS5 TEMP154 VAL = 156.488998 / [K] Red detector package temp.
# HIERARCH ESO INS5 TEMP155 VAL = 147.206985 / [K] Red detector table temp.
# HIERARCH ESO INS5 TEMP16 VAL = 18.567 / [C] Pupil slicer.
# HIERARCH ESO INS5 TEMP17 VAL = 18.687 / [C] Shield 1.
# HIERARCH ESO INS5 TEMP18 VAL = 18.704 / [C] Shield 2.
# HIERARCH ESO INS5 TEMP2 VAL = 18.683 / [C] Echelle grating.
# HIERARCH ESO INS5 TEMP25 VAL = 19.535 / [C] 3T up.
# HIERARCH ESO INS5 TEMP26 VAL = 18.637 / [C] 3T down.
# HIERARCH ESO INS5 TEMP29 VAL = 16.732 / [C] 2T env 1.
# HIERARCH ESO INS5 TEMP3 VAL = 18.679 / [C] Cross disperser blue.
# HIERARCH ESO INS5 TEMP30 VAL = 16.966 / [C] 2T env 2.
# HIERARCH ESO INS5 TEMP31 VAL = 15.125 / [C] 1T env 1.
# HIERARCH ESO INS5 TEMP32 VAL = 15.389 / [C] 1T env 2.
# HIERARCH ESO INS5 TEMP33 REF = 19. / Temperature sensor reference value [C].
# HIERARCH ESO INS5 TEMP33 VAL = 18.997 / [C] VV feet T-sensor primary.
# HIERARCH ESO INS5 TEMP34 VAL = 19.004 / [C] VV feet T-sensor secondary.
# HIERARCH ESO INS5 TEMP35 VAL = 24.826 / [C] FP T-sensor secondary.
# HIERARCH ESO INS5 TEMP36 REF = 25. / [C] FP T-setpoint.
# HIERARCH ESO INS5 TEMP36 VAL = 25.001 / [C] FP T-sensor primary.
# HIERARCH ESO INS5 TEMP37 REF = 19. / [C] 3T T-setpoint.
# HIERARCH ESO INS5 TEMP37 VAL = 18.992 / [C] 3T T-sensor primary.
# HIERARCH ESO INS5 TEMP38 VAL = 19.088 / [C] 3T T-sensor secondary.
# HIERARCH ESO INS5 TEMP4 VAL = 18.654 / [C] Cross disperser red.
# HIERARCH ESO INS5 TEMP41 VAL = 13.6 / [C] FE1 Bench bottom.
# HIERARCH ESO INS5 TEMP42 VAL = 13.5 / [C] FE1 Bench top.
# HIERARCH ESO INS5 TEMP43 VAL = 11.1 / [C] FE1 TCCD field.
# HIERARCH ESO INS5 TEMP44 VAL = 11. / [C] FE1 TCCD pupil.
# HIERARCH ESO INS5 TEMP47 VAL = 13.8 / [C] FE2 Bench bottom.
# HIERARCH ESO INS5 TEMP48 VAL = 13.9 / [C] FE2 Bench top.
# HIERARCH ESO INS5 TEMP49 VAL = 10.9 / [C] FE2 TCCD field.
# HIERARCH ESO INS5 TEMP5 VAL = 18.659 / [C] Dichroic.
# HIERARCH ESO INS5 TEMP50 VAL = 14.8 / [C] FE2 TCCD pupil.
# HIERARCH ESO INS5 TEMP53 VAL = 14. / [C] FE3 Bench bottom.
# HIERARCH ESO INS5 TEMP54 VAL = 13.8 / [C] FE3 Bench top.
# HIERARCH ESO INS5 TEMP55 VAL = 10.5 / [C] FE3 TCCD field.
# HIERARCH ESO INS5 TEMP56 VAL = 10.7 / [C] FE3 TCCD pupil.
# HIERARCH ESO INS5 TEMP59 VAL = 13.7 / [C] FE4 Bench bottom.
# HIERARCH ESO INS5 TEMP6 VAL = 18.726 / [C] Field mirror.
# HIERARCH ESO INS5 TEMP60 VAL = 14. / [C] FE4 Bench top.
# HIERARCH ESO INS5 TEMP61 VAL = 11.3 / [C] FE4 TCCD field.
# HIERARCH ESO INS5 TEMP62 VAL = 11.4 / [C] FE4 TCCD pupil.
# HIERARCH ESO INS5 TEMP65 VAL = 13.1 / [C] Spectro Bench EM.
# HIERARCH ESO INS5 TEMP66 VAL = 11.6 / [C] Spectro TCCD EM.
# HIERARCH ESO INS5 TEMP7 VAL = 18.583 / [C] Transfer coll. blue.
# HIERARCH ESO INS5 TEMP8 VAL = 18.528 / [C] Transfer coll. red.
# HIERARCH ESO INS5 TEMP83 VAL = 14.506667 / [C] Calibration unit cabinet ambinet
# HIERARCH ESO INS5 TEMP9 VAL = 18.752 / [C] Near main collimator.
# HIERARCH ESO INS5 VFILT1 DEN = 0.4 / [D] Position.
# HIERARCH ESO INS5 VFILT1 ENC = 82445 / [Enc] Absolute position.
# HIERARCH ESO INS5 VFILT1 ID = 'ndfila1 ' / Device unique ID.
# HIERARCH ESO INS5 VFILT1 NAME = 'Var ND filter cal A wheel 1' / Variable density
# HIERARCH ESO INS5 VFILT1 POS = 126.0006 / [deg] Position.
# HIERARCH ESO INS5 VFILT2 DEN = 0.4 / [D] Position.
# HIERARCH ESO INS5 VFILT2 ENC = 82445 / [Enc] Absolute position.
# HIERARCH ESO INS5 VFILT2 ID = 'ndfila2 ' / Device unique ID.
# HIERARCH ESO INS5 VFILT2 NAME = 'Var ND filter CAL A wheel 2' / Variable density
# HIERARCH ESO INS5 VFILT2 POS = 126.0006 / [deg] Position.
# HIERARCH ESO INS5 VFILT3 DEN = 0.22 / [D] Position.
# HIERARCH ESO INS5 VFILT3 ENC = 72139 / [Enc] Absolute position.
# HIERARCH ESO INS5 VFILT3 ID = 'ndfilb1 ' / Device unique ID.
# HIERARCH ESO INS5 VFILT3 NAME = 'Var ND filter CAL B wheel 1' / Variable density
# HIERARCH ESO INS5 VFILT3 POS = 110.25 / [deg] Position.
# HIERARCH ESO INS5 VFILT4 DEN = 0.22 / [D] Position.
# HIERARCH ESO INS5 VFILT4 ENC = 72139 / [Enc] Absolute position.
# HIERARCH ESO INS5 VFILT4 ID = 'ndfilb2 ' / Device unique ID.
# HIERARCH ESO INS5 VFILT4 NAME = 'Var ND filter CAL B wheel 2' / Variable density
# HIERARCH ESO INS5 VFILT4 POS = 110.25 / [deg] Position.
# HIERARCH ESO DET BINX =      2 / Setup binning factor along X
# HIERARCH ESO DET BINY =      1 / Setup binning factor along Y
# HIERARCH ESO DET CHIPS =     2 / Number of chips in the mosaic
# HIERARCH ESO DET CON PWIPE = T / Periodic wipe
# HIERARCH ESO DET DEV1 BOARD1 BCKPL = '000010805281' / Serial no (backplane)
# HIERARCH ESO DET DEV1 BOARD1 REV = '5.6.4   ' / Revision
# HIERARCH ESO DET DEV1 BOARD1 SERNO = '000013A6E838' / Serial no (board)
# HIERARCH ESO DET DEV1 BOARD1 TRANS = '0000163DF28F' / Serial no (transition boar
# HIERARCH ESO DET DEV1 BOARD1 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV1 BOARD1 VERSION = 1 / Version
# HIERARCH ESO DET DEV1 BOARD2 BCKPL = '000010805281' / Serial no (backplane)
# HIERARCH ESO DET DEV1 BOARD2 REV = '5.6.4   ' / Revision
# HIERARCH ESO DET DEV1 BOARD2 SERNO = '000011AA6C53' / Serial no (board)
# HIERARCH ESO DET DEV1 BOARD2 TRANS = '0000163DFF54' / Serial no (transition boar
# HIERARCH ESO DET DEV1 BOARD2 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV1 BOARD2 VERSION = 1 / Version
# HIERARCH ESO DET DEV1 BOARD3 BCKPL = '000010805281' / Serial no (backplane)
# HIERARCH ESO DET DEV1 BOARD3 REV = '5.6.4   ' / Revision
# HIERARCH ESO DET DEV1 BOARD3 SERNO = '00001458856D' / Serial no (board)
# HIERARCH ESO DET DEV1 BOARD3 TRANS = '0000163DEBE4' / Serial no (transition boar
# HIERARCH ESO DET DEV1 BOARD3 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV1 BOARD3 VERSION = 1 / Version
# HIERARCH ESO DET DEV1 BOARD4 BCKPL = '000010805281' / Serial no (backplane)
# HIERARCH ESO DET DEV1 BOARD4 REV = '5.6.4   ' / Revision
# HIERARCH ESO DET DEV1 BOARD4 SERNO = '000013A6DAE3' / Serial no (board)
# HIERARCH ESO DET DEV1 BOARD4 TRANS = '0000163DD7F8' / Serial no (transition boar
# HIERARCH ESO DET DEV1 BOARD4 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV1 BOARD4 VERSION = 1 / Version
# HIERARCH ESO DET DEV1 CHIPS = 1 / Number of chips in the mosaic
# HIERARCH ESO DET DEV1 EXP RDTTIME = 37.348 / [s] Image readout time
# HIERARCH ESO DET DEV1 EXP XFERTIM = 37.314 / [s] Image transfer time
# HIERARCH ESO DET DEV1 ID = 'ESPRESSO-BLUE' / Detector system Id
# HIERARCH ESO DET DEV1 OUTPUTS = 16 / Number of outputs
# HIERARCH ESO DET DEV1 REV = '0.4.1   ' / Revision
# HIERARCH ESO DET DEV1 SHUT ID = 'ShEspresso' / Shutter unique identifier
# HIERARCH ESO DET DEV1 SHUT TMCLOS = 0.01 / [s] Time taken to close shutter
# HIERARCH ESO DET DEV1 SHUT TMOPEN = 0.019 / [s] Time taken to open shutter
# HIERARCH ESO DET DEV1 SHUT TYPE = 'Illy    ' / Shutter type
# HIERARCH ESO DET DEV1 SOFW BASE = '306134  ' / Base software version
# HIERARCH ESO DET DEV1 SOFW DETMOD = '315314  ' / Detector module revision
# HIERARCH ESO DET DEV1 SOFW MODE = 'NORMAL  ' / Software operational mode
# HIERARCH ESO DET DEV1 SOFW OPT = '306134  ' / Optical software version
# HIERARCH ESO DET DEV2 BOARD1 BCKPL = '00001080525C' / Serial no (backplane)
# HIERARCH ESO DET DEV2 BOARD1 SERNO = '000014587F6F' / Serial no (board)
# HIERARCH ESO DET DEV2 BOARD1 TRANS = '0000163E0D9B' / Serial no (transition boar
# HIERARCH ESO DET DEV2 BOARD1 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV2 BOARD1 VERSION = 1 / Version
# HIERARCH ESO DET DEV2 BOARD2 BCKPL = '00001080525C' / Serial no (backplane)
# HIERARCH ESO DET DEV2 BOARD2 SERNO = '0000163DBCC3' / Serial no (board)
# HIERARCH ESO DET DEV2 BOARD2 TRANS = '0000163DA9FA' / Serial no (transition boar
# HIERARCH ESO DET DEV2 BOARD2 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV2 BOARD2 VERSION = 1 / Version
# HIERARCH ESO DET DEV2 BOARD3 BCKPL = '00001080525C' / Serial no (backplane)
# HIERARCH ESO DET DEV2 BOARD3 SERNO = '0000163DECA8' / Serial no (board)
# HIERARCH ESO DET DEV2 BOARD3 TRANS = '0000163DAACD' / Serial no (transition boar
# HIERARCH ESO DET DEV2 BOARD3 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV2 BOARD3 VERSION = 1 / Version
# HIERARCH ESO DET DEV2 BOARD4 BCKPL = '00001080525C' / Serial no (backplane)
# HIERARCH ESO DET DEV2 BOARD4 SERNO = '0000163DA5E4' / Serial no (board)
# HIERARCH ESO DET DEV2 BOARD4 TRANS = '00001216DA39' / Serial no (transition boar
# HIERARCH ESO DET DEV2 BOARD4 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV2 BOARD4 VERSION = 1 / Version
# HIERARCH ESO DET DEV2 CHIPS = 1 / Number of chips in the mosaic
# HIERARCH ESO DET DEV2 EXP RDTTIME = 37.345 / [s] Image readout time
# HIERARCH ESO DET DEV2 EXP XFERTIM = 37.309 / [s] Image transfer time
# HIERARCH ESO DET DEV2 ID = 'ESPRESSO-RED' / Detector system Id
# HIERARCH ESO DET DEV2 OUTPUTS = 16 / Number of outputs
# HIERARCH ESO DET DEV2 REV = '0.4.1   ' / Revision
# HIERARCH ESO DET DEV2 SHUT ID = 'dummy   ' / Shutter unique identifier
# HIERARCH ESO DET DEV2 SHUT TMCLOS = 0. / [s] Time taken to close shutter
# HIERARCH ESO DET DEV2 SHUT TMOPEN = 0. / [s] Time taken to open shutter
# HIERARCH ESO DET DEV2 SHUT TYPE = 'nostatus' / Shutter type
# HIERARCH ESO DET DEV2 SOFW BASE = '306134  ' / Base software version
# HIERARCH ESO DET DEV2 SOFW DETMOD = '315314  ' / Detector module revision
# HIERARCH ESO DET DEV2 SOFW MODE = 'NORMAL  ' / Software operational mode
# HIERARCH ESO DET DEV2 SOFW OPT = '306134  ' / Optical software version
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.NGCDCS,ESO-VLT-DIC.NGCCON' / Used di
# HIERARCH ESO DET DIT1 =   300. / [s] Actual subintegration time
# HIERARCH ESO DET DKTM =   300. / [s] Dark current time
# HIERARCH ESO DET EXP NO =   33 / Unique exposure ID number
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET NAME = 'ESPRESSO-BLUE' / Name of detector system
# HIERARCH ESO DET NDIT =      1 / Number of Sub-Integrations
# HIERARCH ESO DET OUTPUTS =  32 / Number of outputs
# HIERARCH ESO DET READ CURID = 8 / Used readout mode id
# HIERARCH ESO DET READ CURNAME = 'Slow    ' / Used readout mode name
# HIERARCH ESO DET UIT1 =   300. / [s] User defined subintegration ti
# HIERARCH ESO PRO CATG = 'S2D_SKYSUB_A' / Category of pipeline product frame
# HIERARCH ESO PRO ANCESTOR = 'ESPRE.2018-10-31T01:11:53.462.fits'
# HIERARCH ESO PRO DID = 'PRO-1.16' / Data dictionary for PRO
# HIERARCH ESO PRO TYPE = 'REDUCED ' / Product type
# HIERARCH ESO PRO TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO SCIENCE =   T / Scientific product if T
# HIERARCH ESO PRO REC1 ID = 'espdr_sci_red' / Pipeline recipe (unique) identifier
# HIERARCH ESO PRO REC1 DRS ID = 'cpl-7.1.3' / Data Reduction System identifier
# HIERARCH ESO PRO REC1 PIPE ID = 'espdr/2.2.1' / Pipeline (unique) identifier
# HIERARCH ESO PRO REC1 RAW1 NAME = 'ESPRE.2018-10-31T01:11:53.462.fits' / File na
# HIERARCH ESO PRO REC1 RAW1 CATG = 'OBJ_SKY ' / Category of raw frame
# HIERARCH ESO PRO DATANCOM =  1 / Number of combined frames
# HIERARCH ESO PRO REC1 CAL1 NAME = 'ESPRESSO_2x1_CCD_geom_config.fits' / File nam
# HIERARCH ESO PRO REC1 CAL1 CATG = 'CCD_GEOM' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL2 NAME= 'ESPRESSO_SINGLEHR_2x1_reduced_inst_config_201'
# HIERARCH ESO PRO REC1 CAL2 CATG = 'INST_CONFIG' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL3 NAME = 'ESPRESSO_master_bias_res.fits' / File name of
# HIERARCH ESO PRO REC1 CAL3 CATG = 'MASTER_BIAS_RES' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL3 DATAMD5 = '55b9020850df02a267fd0176dc973b58' / MD5 si
# HIERARCH ESO PRO REC1 CAL4 NAME = 'ESPRESSO_hot_pixels.fits' / File name of cali
# HIERARCH ESO PRO REC1 CAL4 CATG = 'HOT_PIXEL_MASK' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL4 DATAMD5 = 'ce9e230f30d3e7fe57f3291b92ebecb3' / MD5 si
# HIERARCH ESO PRO REC1 CAL5 NAME = 'ESPRESSO_bad_pixels.fits' / File name of cali
# HIERARCH ESO PRO REC1 CAL5 CATG = 'BAD_PIXEL_MASK' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL5 DATAMD5 = '0540d6353ed3326c7d7cf8bab18838de' / MD5 si
# HIERARCH ESO PRO REC1 CAL6 NAME = 'ESPRESSO_ORDER_TABLE_A.fits' / File name of c
# HIERARCH ESO PRO REC1 CAL6 CATG = 'ORDER_TABLE_A' / Category of calibration fram
# HIERARCH ESO PRO REC1 CAL6 DATAMD5 = '0ed7c8b19e90512ed618320d19451210' / MD5 si
# HIERARCH ESO PRO REC1 CAL7 NAME = 'ESPRESSO_ORDER_TABLE_B.fits' / File name of c
# HIERARCH ESO PRO REC1 CAL7 CATG = 'ORDER_TABLE_B' / Category of calibration fram
# HIERARCH ESO PRO REC1 CAL7 DATAMD5 = '286539512cd4ede19d76d07ed469cbdf' / MD5 si
# HIERARCH ESO PRO REC1 CAL8 NAME = 'ESPRESSO_ORDER_PROFILE_A.fits' / File name of
# HIERARCH ESO PRO REC1 CAL8 CATG = 'ORDER_PROFILE_A' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL8 DATAMD5 = 'a35e378612c004a91a564b558653d22b' / MD5 si
# HIERARCH ESO PRO REC1 CAL9 NAME = 'ESPRESSO_ORDER_PROFILE_B.fits' / File name of
# HIERARCH ESO PRO REC1 CAL9 CATG = 'ORDER_PROFILE_B' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL9 DATAMD5 = '1591193b2eb100e7cec95631c735f83a' / MD5 si
# HIERARCH ESO PRO REC1 CAL10 NAME = 'ESPRESSO_FLAT_A.fits' / File name of calibra
# HIERARCH ESO PRO REC1 CAL10 CATG = 'FSPECTRUM_A' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL10 DATAMD5 = '383d22b8a66190b40ed0c0eace88dc28' / MD5 s
# HIERARCH ESO PRO REC1 CAL11 NAME = 'ESPRESSO_FLAT_B.fits' / File name of calibra
# HIERARCH ESO PRO REC1 CAL11 CATG = 'FSPECTRUM_B' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL11 DATAMD5 = '8b6442e88a1a09986e7ef38046594dd1' / MD5 s
# HIERARCH ESO PRO REC1 CAL12 NAME = 'ESPRESSO_BLAZE_A.fits' / File name of calibr
# HIERARCH ESO PRO REC1 CAL12 CATG = 'BLAZE_A ' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL12 DATAMD5 = '96782ba51fafe5d661fb393f91632d8f' / MD5 s
# HIERARCH ESO PRO REC1 CAL13 NAME = 'ESPRESSO_BLAZE_B.fits' / File name of calibr
# HIERARCH ESO PRO REC1 CAL13 CATG = 'BLAZE_B ' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL13 DATAMD5 = '7a45091f628d33379e519098d36bb619' / MD5 s
# HIERARCH ESO PRO REC1 CAL14 NAME = 'ESPRESSO_WAVE_MATRIX_A.fits' / File name of
# HIERARCH ESO PRO REC1 CAL14 CATG = 'WAVE_MATRIX_THAR_FP_A' / Category of calibra
# HIERARCH ESO PRO REC1 CAL14 DATAMD5 = '62e6597f279651346682f35bae1d0be6' / MD5 s
# HIERARCH ESO PRO REC1 CAL15 NAME = 'ESPRESSO_WAVE_MATRIX_B.fits' / File name of
# HIERARCH ESO PRO REC1 CAL15 CATG = 'WAVE_MATRIX_FP_THAR_B' / Category of calibra
# HIERARCH ESO PRO REC1 CAL15 DATAMD5 = 'a90fbe6438053139033ee6a95bd327d7' / MD5 s
# HIERARCH ESO PRO REC1 CAL16 NAME = 'ESPRESSO_DLL_MATRIX_A.fits' / File name of c
# HIERARCH ESO PRO REC1 CAL16 CATG = 'DLL_MATRIX_THAR_FP_A' / Category of calibrat
# HIERARCH ESO PRO REC1 CAL16 DATAMD5 = '052fd8c3def863df820bd3375c765fed' / MD5 s
# HIERARCH ESO PRO REC1 CAL17 NAME = 'ESPRESSO_DLL_MATRIX_B.fits' / File name of c
# HIERARCH ESO PRO REC1 CAL17 CATG = 'DLL_MATRIX_FP_THAR_B' / Category of calibrat
# HIERARCH ESO PRO REC1 CAL17 DATAMD5 = '182e58b98fca8a1d9f6b6c51f266b6d0' / MD5 s
# HIERARCH ESO PRO REC1 CAL18 NAME = 'ESPRESSO_REL_EFF_B.fits' / File name of cali
# HIERARCH ESO PRO REC1 CAL18 CATG = 'REL_EFF_B' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL18 DATAMD5 = '956de464fd413b64c2b41c3ebb6d82e6' / MD5 s
# HIERARCH ESO PRO REC1 CAL19 NAME = 'ESPRESSO_ABS_EFF_A.fits' / File name of cali
# HIERARCH ESO PRO REC1 CAL19 CATG = 'ABS_EFF_A' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL19 DATAMD5 = '6d3438c8385bf5ee4972440ef4a9193a' / MD5 s
# HIERARCH ESO PRO REC1 CAL20 NAME = 'ESPRESSO_EXTINCTION_TABLE.fits' / File name
# HIERARCH ESO PRO REC1 CAL20 CATG = 'EXT_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL21 NAME = 'ESPRESSO_mask_lut.fits' / File name of calib
# HIERARCH ESO PRO REC1 CAL21 CATG = 'MASK_LUT' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL22 NAME = 'ESPRESSO_SINGLEHR_2x1_FLUX_TEMPLATE.fits'
# HIERARCH ESO PRO REC1 CAL22 CATG = 'FLUX_TEMPLATE' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL23 NAME = 'ESPRESSO_F9.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL23 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL24 NAME = 'ESPRESSO_G2.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL24 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL25 NAME = 'ESPRESSO_G8.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL25 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL26 NAME = 'ESPRESSO_G9.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL26 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL27 NAME = 'ESPRESSO_K2.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL27 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL28 NAME = 'ESPRESSO_K6.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL28 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL29 NAME = 'ESPRESSO_M0.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL29 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL30 NAME = 'ESPRESSO_M2.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL30 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL31 NAME = 'ESPRESSO_M3.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL31 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL32 NAME = 'ESPRESSO_M4.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL32 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL33 NAME = 'ESPRESSO_M5.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL33 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 PARAM1 NAME = 'ovsc_sig_clip_method' / method for sigma cl
# HIERARCH ESO PRO REC1 PARAM1 VALUE = 'mean    ' / Default: 'mean'
# HIERARCH ESO PRO REC1 PARAM2 NAME = 'ovsc_ksigma' / ksigma for sigma clipping in
# HIERARCH ESO PRO REC1 PARAM2 VALUE = '4       ' / Default: 4
# HIERARCH ESO PRO REC1 PARAM3 NAME = 'ovsc_max_iter' / maximal number of iteratio
# HIERARCH ESO PRO REC1 PARAM3 VALUE = '10      ' / Default: 10
# HIERARCH ESO PRO REC1 PARAM4 NAME = 'background_sw' / Background subtraction act
# HIERARCH ESO PRO REC1 PARAM4 VALUE = 'off     ' / Default: 'on'
# HIERARCH ESO PRO REC1 PARAM5 NAME = 'sci_bkgr_grid_size_x' / Grid size in x used
# HIERARCH ESO PRO REC1 PARAM5 VALUE = '577     ' / Default: 577
# HIERARCH ESO PRO REC1 PARAM6 NAME = 'sci_bkgr_grid_size_y' / Grid size in y used
# HIERARCH ESO PRO REC1 PARAM6 VALUE = '256     ' / Default: 256
# HIERARCH ESO PRO REC1 PARAM7 NAME = 'wave_cal_source' / Wavelength calibration s
# HIERARCH ESO PRO REC1 PARAM7 VALUE = 'THAR    ' / Default: 'THAR'
# HIERARCH ESO PRO REC1 PARAM8 NAME = 'mask_table_id' / Mask table to be used, def
# HIERARCH ESO PRO REC1 PARAM8 VALUE = 'XX      ' / Default: 'XX'
# HIERARCH ESO PRO REC1 PARAM9 NAME = 'rv_center' / Approximate RV. In case of def
# HIERARCH ESO PRO REC1 PARAM9 VALUE = '-9999   ' / Default: -9999
# HIERARCH ESO PRO REC1 PARAM10 NAME = 'rv_range' / Range for the RV table.
# HIERARCH ESO PRO REC1 PARAM10 VALUE = '20      ' / Default: 20
# HIERARCH ESO PRO REC1 PARAM11 NAME = 'rv_step ' / Range's step for the RV table.
# HIERARCH ESO PRO REC1 PARAM11 VALUE = '0.5     ' / Default: 0.5
# HIERARCH ESO PRO REC1 PARAM12 NAME = 'extraction_method' / Method used to extrac
# HIERARCH ESO PRO REC1 PARAM12 VALUE = 'horne   ' / Default: 'horne'
# HIERARCH ESO PRO REC1 PARAM13 NAME = 'ksigma_cosmic' / ksigma for removing cosmi
# HIERARCH ESO PRO REC1 PARAM13 VALUE = '3.5     ' / Default: 3.5
# HIERARCH ESO PRO REC1 PARAM14 NAME = 'bias_res_removal_sw' / Flag indicating to
# HIERARCH ESO PRO REC1 PARAM14 VALUE = 'on      ' / Default: 'on'
# HIERARCH ESO PRO REC1 PARAM15 NAME = 'flux_correction_type' / Flux correction: N
# HIERARCH ESO PRO REC1 PARAM15 VALUE = 'AUTO    ' / Default: 'AUTO'
# HIERARCH ESO PRO REC1 PARAM16 NAME = 'drift_correction_sw' / Drift correction ac
# HIERARCH ESO PRO REC1 PARAM16 VALUE = 'on      ' / Default: 'on'
# HIERARCH ESO PRO REC1 PARAM17 NAME = 'drift_method_fp' / Method adopted to compu
# HIERARCH ESO PRO REC1 PARAM17 VALUE = 'flux_global_drift_global_sequential_fit'
# HIERARCH ESO PRO REC1 PARAM18 NAME = 'drift_space' / Space to compute drift (pix
# HIERARCH ESO PRO REC1 PARAM18 VALUE = 'pixel   ' / Default: 'pixel'
# HIERARCH ESO PRO REC1 PARAM19 NAME = 'drift_ksigma' / ksigma for computing drift
# HIERARCH ESO PRO REC1 PARAM19 VALUE = '50      ' / Default: 50
# HIERARCH ESO PRO REC1 PARAM20 NAME = 'sky_sub_method' / Method used to subtract
# HIERARCH ESO PRO REC1 PARAM20 VALUE = 'pixel-by-pixel' / Default: 'pixel-by-pixe
# ...
# HIERARCH ESO QC THAR LAMP OFFSET AR = -9999.9 / TH lamp offset AR [m/s]
# HIERARCH ESO QC THAR LAMP OFFSET AR1 = -9999.9 / TH lamp offset AR1 [m/s]
# HIERARCH ESO QC THAR LAMP OFFSET AR2 = -9999.9 / TH lamp offset AR2 [m/s]
# HIERARCH ESO QC EXT0 BKGR MEAN = -9999.9 / Bkgr mean [e-] in the extension
# HIERARCH ESO QC EXT0 BKGR MIN = -9999.9 / Bkgr min [e-] in the extension
# HIERARCH ESO QC EXT0 BKGR MAX = -9999.9 / Bkgr max [e-] in the extension
# HIERARCH ESO QC EXT1 BKGR MEAN = -9999.9 / Bkgr mean [e-] in the extension
# HIERARCH ESO QC EXT1 BKGR MIN = -9999.9 / Bkgr min [e-] in the extension
# HIERARCH ESO QC EXT1 BKGR MAX = -9999.9 / Bkgr max [e-] in the extension
# HIERARCH ESO QC ORDER1 FLUX CORR = 1.03452242216284 / Flux corr for the order
# HIERARCH ESO QC ORDER2 FLUX CORR = 1.03451081656766 / Flux corr for the order
# HIERARCH ESO QC ORDER3 FLUX CORR = 0.992969996726146 / Flux corr for the order
# HIERARCH ESO QC ORDER4 FLUX CORR = 0.992961070321655 / Flux corr for the order
# HIERARCH ESO QC ORDER5 FLUX CORR = 0.95727204981813 / Flux corr for the order
# HIERARCH ESO QC ORDER6 FLUX CORR = 0.957265146523611 / Flux corr for the order
# HIERARCH ESO QC ORDER7 FLUX CORR = 0.927105147583831 / Flux corr for the order
# HIERARCH ESO QC ORDER8 FLUX CORR = 0.927099884891305 / Flux corr for the order
# HIERARCH ESO QC ORDER9 FLUX CORR = 0.902144701365671 / Flux corr for the order
# HIERARCH ESO QC ORDER10 FLUX CORR = 0.902140750716484 / Flux corr for the order
# HIERARCH ESO QC ORDER11 FLUX CORR = 0.882065343590824 / Flux corr for the order
# HIERARCH ESO QC ORDER12 FLUX CORR = 0.882062443276737 / Flux corr for the order
# HIERARCH ESO QC ORDER13 FLUX CORR = 0.866541526258544 / Flux corr for the order
# HIERARCH ESO QC ORDER14 FLUX CORR = 0.866539501487495 / Flux corr for the order
# HIERARCH ESO QC ORDER15 FLUX CORR = 0.855248214694228 / Flux corr for the order
# HIERARCH ESO QC ORDER16 FLUX CORR = 0.855246857216429 / Flux corr for the order
# HIERARCH ESO QC ORDER17 FLUX CORR = 0.847861351684259 / Flux corr for the order
# HIERARCH ESO QC ORDER18 FLUX CORR = 0.847860568124531 / Flux corr for the order
# HIERARCH ESO QC ORDER19 FLUX CORR = 0.844058657825911 / Flux corr for the order
# HIERARCH ESO QC ORDER20 FLUX CORR = 0.84405836243505 / Flux corr for the order
# HIERARCH ESO QC ORDER21 FLUX CORR = 0.843520264661976 / Flux corr for the order
# HIERARCH ESO QC ORDER22 FLUX CORR = 0.843520402315676 / Flux corr for the order
# HIERARCH ESO QC ORDER23 FLUX CORR = 0.845929463956139 / Flux corr for the order
# HIERARCH ESO QC ORDER24 FLUX CORR = 0.845929997757679 / Flux corr for the order
# HIERARCH ESO QC ORDER25 FLUX CORR = 0.850973467499671 / Flux corr for the order
# HIERARCH ESO QC ORDER26 FLUX CORR = 0.850974365230485 / Flux corr for the order
# HIERARCH ESO QC ORDER27 FLUX CORR = 0.858344182832951 / Flux corr for the order
# HIERARCH ESO QC ORDER28 FLUX CORR = 0.858345429316955 / Flux corr for the order
# HIERARCH ESO QC ORDER29 FLUX CORR = 0.867739054489505 / Flux corr for the order
# HIERARCH ESO QC ORDER30 FLUX CORR = 0.867740622080049 / Flux corr for the order
# HIERARCH ESO QC ORDER31 FLUX CORR = 0.878861861264625 / Flux corr for the order
# HIERARCH ESO QC ORDER32 FLUX CORR = 0.878863726351142 / Flux corr for the order
# HIERARCH ESO QC ORDER33 FLUX CORR = 0.891423608662762 / Flux corr for the order
# HIERARCH ESO QC ORDER34 FLUX CORR = 0.891425754514557 / Flux corr for the order
# HIERARCH ESO QC ORDER35 FLUX CORR = 0.905143420624881 / Flux corr for the order
# HIERARCH ESO QC ORDER36 FLUX CORR = 0.905145805207439 / Flux corr for the order
# HIERARCH ESO QC ORDER37 FLUX CORR = 0.919749403288961 / Flux corr for the order
# HIERARCH ESO QC ORDER38 FLUX CORR = 0.919751988469159 / Flux corr for the order
# HIERARCH ESO QC ORDER39 FLUX CORR = 0.934979552413097 / Flux corr for the order
# HIERARCH ESO QC ORDER40 FLUX CORR = 0.934982304433959 / Flux corr for the order
# HIERARCH ESO QC ORDER41 FLUX CORR = 0.950582695982177 / Flux corr for the order
# HIERARCH ESO QC ORDER42 FLUX CORR = 0.950585574361469 / Flux corr for the order
# HIERARCH ESO QC ORDER43 FLUX CORR = 0.966319395033452 / Flux corr for the order
# HIERARCH ESO QC ORDER44 FLUX CORR = 0.966322352447378 / Flux corr for the order
# HIERARCH ESO QC ORDER45 FLUX CORR = 0.981962857402323 / Flux corr for the order
# HIERARCH ESO QC ORDER46 FLUX CORR = 0.981965830202398 / Flux corr for the order
# HIERARCH ESO QC ORDER47 FLUX CORR = 0.997299854245 / Flux corr for the order
# HIERARCH ESO QC ORDER48 FLUX CORR = 0.997302804167191 / Flux corr for the order
# HIERARCH ESO QC ORDER49 FLUX CORR = 1.01213166074365 / Flux corr for the order
# HIERARCH ESO QC ORDER50 FLUX CORR = 1.01213453614588 / Flux corr for the order
# HIERARCH ESO QC ORDER51 FLUX CORR = 1.02627490563475 / Flux corr for the order
# HIERARCH ESO QC ORDER52 FLUX CORR = 1.02627766830733 / Flux corr for the order
# HIERARCH ESO QC ORDER53 FLUX CORR = 1.0395624332503 / Flux corr for the order
# HIERARCH ESO QC ORDER54 FLUX CORR = 1.03956501696587 / Flux corr for the order
# HIERARCH ESO QC ORDER55 FLUX CORR = 1.05184404469122 / Flux corr for the order
# HIERARCH ESO QC ORDER56 FLUX CORR = 1.05184641068951 / Flux corr for the order
# HIERARCH ESO QC ORDER57 FLUX CORR = 1.06298735452572 / Flux corr for the order
# HIERARCH ESO QC ORDER58 FLUX CORR = 1.06298947934442 / Flux corr for the order
# HIERARCH ESO QC ORDER59 FLUX CORR = 1.07287848696126 / Flux corr for the order
# HIERARCH ESO QC ORDER60 FLUX CORR = 1.07288034035594 / Flux corr for the order
# HIERARCH ESO QC ORDER61 FLUX CORR = 1.08142266059622 / Flux corr for the order
# HIERARCH ESO QC ORDER62 FLUX CORR = 1.08142420570812 / Flux corr for the order
# HIERARCH ESO QC ORDER63 FLUX CORR = 1.08854474381815 / Flux corr for the order
# HIERARCH ESO QC ORDER64 FLUX CORR = 1.08854597215793 / Flux corr for the order
# HIERARCH ESO QC ORDER65 FLUX CORR = 1.09418975384995 / Flux corr for the order
# HIERARCH ESO QC ORDER66 FLUX CORR = 1.09419068026693 / Flux corr for the order
# HIERARCH ESO QC ORDER67 FLUX CORR = 1.09832319885254 / Flux corr for the order
# HIERARCH ESO QC ORDER68 FLUX CORR = 1.09832381886099 / Flux corr for the order
# HIERARCH ESO QC ORDER69 FLUX CORR = 1.10093124027389 / Flux corr for the order
# HIERARCH ESO QC ORDER70 FLUX CORR = 1.10093156646292 / Flux corr for the order
# HIERARCH ESO QC ORDER71 FLUX CORR = 1.10202081546163 / Flux corr for the order
# HIERARCH ESO QC ORDER72 FLUX CORR = 1.10202087254982 / Flux corr for the order
# HIERARCH ESO QC ORDER73 FLUX CORR = 1.10161955918204 / Flux corr for the order
# HIERARCH ESO QC ORDER74 FLUX CORR = 1.10161937646853 / Flux corr for the order
# HIERARCH ESO QC ORDER75 FLUX CORR = 1.09977553292254 / Flux corr for the order
# HIERARCH ESO QC ORDER76 FLUX CORR = 1.09977514672823 / Flux corr for the order
# HIERARCH ESO QC ORDER77 FLUX CORR = 1.09655678801948 / Flux corr for the order
# HIERARCH ESO QC ORDER78 FLUX CORR = 1.0965562390071 / Flux corr for the order
# HIERARCH ESO QC ORDER79 FLUX CORR = 1.09205071364352 / Flux corr for the order
# HIERARCH ESO QC ORDER80 FLUX CORR = 1.09205004093906 / Flux corr for the order
# HIERARCH ESO QC ORDER81 FLUX CORR = 1.08636314742546 / Flux corr for the order
# HIERARCH ESO QC ORDER82 FLUX CORR = 1.08636239157818 / Flux corr for the order
# HIERARCH ESO QC ORDER83 FLUX CORR = 1.07961724640359 / Flux corr for the order
# HIERARCH ESO QC ORDER84 FLUX CORR = 1.07961644276179 / Flux corr for the order
# HIERARCH ESO QC ORDER85 FLUX CORR = 1.07195211730573 / Flux corr for the order
# HIERARCH ESO QC ORDER86 FLUX CORR = 1.07195129124102 / Flux corr for the order
# HIERARCH ESO QC ORDER87 FLUX CORR = 1.06352115974573 / Flux corr for the order
# HIERARCH ESO QC ORDER88 FLUX CORR = 1.06352032834434 / Flux corr for the order
# HIERARCH ESO QC ORDER89 FLUX CORR = 1.05449015932095 / Flux corr for the order
# HIERARCH ESO QC ORDER90 FLUX CORR = 1.05448933123148 / Flux corr for the order
# HIERARCH ESO QC ORDER91 FLUX CORR = 1.05409258377176 / Flux corr for the order
# HIERARCH ESO QC ORDER92 FLUX CORR = 1.054091851679 / Flux corr for the order
# HIERARCH ESO QC ORDER93 FLUX CORR = 1.04462973937507 / Flux corr for the order
# HIERARCH ESO QC ORDER94 FLUX CORR = 1.04462889115962 / Flux corr for the order
# HIERARCH ESO QC ORDER95 FLUX CORR = 1.03493454565864 / Flux corr for the order
# HIERARCH ESO QC ORDER96 FLUX CORR = 1.03493377442237 / Flux corr for the order
# HIERARCH ESO QC ORDER97 FLUX CORR = 1.02519505717851 / Flux corr for the order
# HIERARCH ESO QC ORDER98 FLUX CORR = 1.02519437888395 / Flux corr for the order
# HIERARCH ESO QC ORDER99 FLUX CORR = 1.01560093150192 / Flux corr for the order
# HIERARCH ESO QC ORDER100 FLUX CORR = 1.01560033621263 / Flux corr for the order
# HIERARCH ESO QC ORDER101 FLUX CORR = 1.00634008088514 / Flux corr for the order
# HIERARCH ESO QC ORDER102 FLUX CORR = 1.00633957653986 / Flux corr for the order
# HIERARCH ESO QC ORDER103 FLUX CORR = 0.997595005764197 / Flux corr for the order
# HIERARCH ESO QC ORDER104 FLUX CORR = 0.997594575399944 / Flux corr for the order
# HIERARCH ESO QC ORDER105 FLUX CORR = 0.98953904655059 / Flux corr for the order
# HIERARCH ESO QC ORDER106 FLUX CORR = 0.989538684482795 / Flux corr for the order
# HIERARCH ESO QC ORDER107 FLUX CORR = 0.982332366576202 / Flux corr for the order
# HIERARCH ESO QC ORDER108 FLUX CORR = 0.982332061351372 / Flux corr for the order
# HIERARCH ESO QC ORDER109 FLUX CORR = 0.976117909131517 / Flux corr for the order
# HIERARCH ESO QC ORDER110 FLUX CORR = 0.976117662470642 / Flux corr for the order
# HIERARCH ESO QC ORDER111 FLUX CORR = 0.971017371504331 / Flux corr for the order
# HIERARCH ESO QC ORDER112 FLUX CORR = 0.971017175906127 / Flux corr for the order
# HIERARCH ESO QC ORDER113 FLUX CORR = 0.967127205981342 / Flux corr for the order
# HIERARCH ESO QC ORDER114 FLUX CORR = 0.967127062168856 / Flux corr for the order
# HIERARCH ESO QC ORDER115 FLUX CORR = 0.964514861802854 / Flux corr for the order
# HIERARCH ESO QC ORDER116 FLUX CORR = 0.964514772761504 / Flux corr for the order
# HIERARCH ESO QC ORDER117 FLUX CORR = 0.963215461288655 / Flux corr for the order
# HIERARCH ESO QC ORDER118 FLUX CORR = 0.963215430932905 / Flux corr for the order
# HIERARCH ESO QC ORDER119 FLUX CORR = 0.963228933058872 / Flux corr for the order
# HIERARCH ESO QC ORDER120 FLUX CORR = 0.96322896528909 / Flux corr for the order
# HIERARCH ESO QC ORDER121 FLUX CORR = 0.96451795069197 / Flux corr for the order
# HIERARCH ESO QC ORDER122 FLUX CORR = 0.964518047448564 / Flux corr for the order
# HIERARCH ESO QC ORDER123 FLUX CORR = 0.967006842131468 / Flux corr for the order
# HIERARCH ESO QC ORDER124 FLUX CORR = 0.967007008469409 / Flux corr for the order
# HIERARCH ESO QC ORDER125 FLUX CORR = 0.970581721018789 / Flux corr for the order
# HIERARCH ESO QC ORDER126 FLUX CORR = 0.970581961083553 / Flux corr for the order
# HIERARCH ESO QC ORDER127 FLUX CORR = 0.975092138035507 / Flux corr for the order
# HIERARCH ESO QC ORDER128 FLUX CORR = 0.975092430505811 / Flux corr for the order
# HIERARCH ESO QC ORDER129 FLUX CORR = 0.980354661289311 / Flux corr for the order
# HIERARCH ESO QC ORDER130 FLUX CORR = 0.980355006408899 / Flux corr for the order
# HIERARCH ESO QC ORDER131 FLUX CORR = 0.986158378000255 / Flux corr for the order
# HIERARCH ESO QC ORDER132 FLUX CORR = 0.986158768774658 / Flux corr for the order
# HIERARCH ESO QC ORDER133 FLUX CORR = 0.992273007537733 / Flux corr for the order
# HIERARCH ESO QC ORDER134 FLUX CORR = 0.992273427724285 / Flux corr for the order
# HIERARCH ESO QC ORDER135 FLUX CORR = 0.998459559892581 / Flux corr for the order
# HIERARCH ESO QC ORDER136 FLUX CORR = 0.998459992083554 / Flux corr for the order
# HIERARCH ESO QC ORDER137 FLUX CORR = 1.00448394978139 / Flux corr for the order
# HIERARCH ESO QC ORDER138 FLUX CORR = 1.00448437545037 / Flux corr for the order
# HIERARCH ESO QC ORDER139 FLUX CORR = 1.01013340721056 / Flux corr for the order
# HIERARCH ESO QC ORDER140 FLUX CORR = 1.01013380812037 / Flux corr for the order
# HIERARCH ESO QC ORDER141 FLUX CORR = 1.01523573997292 / Flux corr for the order
# HIERARCH ESO QC ORDER142 FLUX CORR = 1.01523610336972 / Flux corr for the order
# HIERARCH ESO QC ORDER143 FLUX CORR = 1.01968088345984 / Flux corr for the order
# HIERARCH ESO QC ORDER144 FLUX CORR = 1.01968119627782 / Flux corr for the order
# HIERARCH ESO QC ORDER145 FLUX CORR = 1.02344387902849 / Flux corr for the order
# HIERARCH ESO QC ORDER146 FLUX CORR = 1.02344413954506 / Flux corr for the order
# HIERARCH ESO QC ORDER147 FLUX CORR = 1.02660771551928 / Flux corr for the order
# HIERARCH ESO QC ORDER148 FLUX CORR = 1.02660793556061 / Flux corr for the order
# HIERARCH ESO QC ORDER149 FLUX CORR = 1.02938378921499 / Flux corr for the order
# HIERARCH ESO QC ORDER150 FLUX CORR = 1.0293839917922 / Flux corr for the order
# HIERARCH ESO QC ORDER151 FLUX CORR = 1.03212626685854 / Flux corr for the order
# HIERARCH ESO QC ORDER152 FLUX CORR = 1.03212647506552 / Flux corr for the order
# HIERARCH ESO QC ORDER153 FLUX CORR = 1.03533512350259 / Flux corr for the order
# HIERARCH ESO QC ORDER154 FLUX CORR = 1.03533536907162 / Flux corr for the order
# HIERARCH ESO QC ORDER155 FLUX CORR = 1.03964038373306 / Flux corr for the order
# HIERARCH ESO QC ORDER156 FLUX CORR = 1.03964069746144 / Flux corr for the order
# HIERARCH ESO QC ORDER157 FLUX CORR = 1.04575700550959 / Flux corr for the order
# HIERARCH ESO QC ORDER158 FLUX CORR = 1.04575741366534 / Flux corr for the order
# HIERARCH ESO QC ORDER159 FLUX CORR = 1.0543957863174 / Flux corr for the order
# HIERARCH ESO QC ORDER160 FLUX CORR = 1.05439629231114 / Flux corr for the order
# HIERARCH ESO QC ORDER161 FLUX CORR = 1.06611034827438 / Flux corr for the order
# HIERARCH ESO QC ORDER162 FLUX CORR = 1.06611093978972 / Flux corr for the order
# HIERARCH ESO QC ORDER163 FLUX CORR = 1.0810526317382 / Flux corr for the order
# HIERARCH ESO QC ORDER164 FLUX CORR = 1.08105317973241 / Flux corr for the order
# HIERARCH ESO QC ORDER165 FLUX CORR = 1.09860038230909 / Flux corr for the order
# HIERARCH ESO QC ORDER166 FLUX CORR = 1.09860081941952 / Flux corr for the order
# HIERARCH ESO QC ORDER167 FLUX CORR = 1.11680678348421 / Flux corr for the order
# HIERARCH ESO QC ORDER168 FLUX CORR = 1.1168070081294 / Flux corr for the order
# HIERARCH ESO QC ORDER169 FLUX CORR = 1.13160460332074 / Flux corr for the order
# HIERARCH ESO QC ORDER170 FLUX CORR = 1.13160462363521 / Flux corr for the order
# HIERARCH ESO QC FLUX CORR MIN = 0.843520264661976 / Min of flux correction
# HIERARCH ESO QC FLUX CORR MAX = 1.13160462363521 / Max of flux correction
# HIERARCH ESO QC SCIRED FLUX CORR CHECK = 1 / Flux correction QC
# HIERARCH ESO QC CCF RV = -1.11454678555515 / Radial velocity [km/s]
# HIERARCH ESO QC CCF RV ERROR = 0.00100213005604942 / Uncertainty on radial veloc
# HIERARCH ESO QC CCF FWHM = 9.48490190618907 / CCF FWHM [km/s]
# HIERARCH ESO QC CCF FWHM ERROR = 0.00200426011209885 / Uncertainty on CCF FWHM [
# HIERARCH ESO QC CCF CONTRAST = 60.2209731159562 / CCF contrast %
# HIERARCH ESO QC CCF CONTRAST ERROR = 0.0127253286878307 / CCF contrast error %
# HIERARCH ESO QC CCF CONTINUUM = 824200.174317837 / CCF continuum level [e-]
# HIERARCH ESO QC CCF MASK = 'F9      ' / CCF mask used
# HIERARCH ESO QC CCF FLUX ASYMMETRY = 0.0145937125582403 / CCF asymmetry (km/s)
# HIERARCH ESO QC CCF FLUX ASYMMETRY ERROR = 0.00166591727500908 / CCF asymmetry e
# HIERARCH ESO QC CCF BIS SPAN = -0.0189005601797803 / CCF bisector span (km/s)
# HIERARCH ESO QC CCF BIS SPAN ERROR = 0.00200426011209885 / CCF bisector span err
# HIERARCH ESO QC SCIRED CHECK = 1 / SCIRED global QC
# CHECKSUM= '90jfH0gf90gfE0gf'   / HDU checksum updated 2022-02-10T19:56:30
# DATASUM = '         0'         / data unit checksum updated 2022-02-10T19:56:30

# %% [markdown]
# Now we load the actual spectra.

# %%
def read_S2D(hdus):
    """S2D hdu structure (works for any S2D file):

    1: science
    2: errors
    3: data quality flag
    4: wavelength vacuum
    5: wavelength air
    6: pixel width vacuum
    7: pixel width air

    Output: (exposure, order, pixel)

    Every physical order is represented twice in the S2D spectrum.

    From the manual:
    In the case of ESPRESSO, pupil slicing and anamorphic magnification are used to achieve high spectral resolution while using a grating with the same size as that of HARPS. The slit image on the detector is made of two ellipsoidal slices aligned in cross-dispersion direction. For the modes with the two slices of an order well separated on the CCD (SINGLEHR11, SINGLEHR21 and SINGLEUHR), each slice is extracted separately and treated as if it was an independent interference order. This results in each physical order being represented twice in the S2D extracted spectrum.
    """


    S2D_wavelengths_vacuum_bary = []
    S2D_spectra = []
    S2D_errors = []

    for n, hdu in enumerate(hdus):
        try:
            S2D_wavelengths_vacuum_bary.append(hdu[4].data)
        except:
            import pdb
            pdb.set_trace()
        S2D_spectra.append(hdu[1].data)
        S2D_errors.append(hdu[2].data)

    return np.array(S2D_wavelengths_vacuum_bary), np.array(S2D_spectra), np.array(S2D_errors)

# %%
S2D_wavelengths_vacuum_bary, S2D_spectra, S2D_errors = read_S2D(hdus_S2D)

# %% [markdown]
# We want to look at the spectra. Since we will do that many times, let's define functions

# %%
# (exposure, order, pixel)

def plot_single_exposure(S2D_spectra, exp_index, cmap = matplotlib.cm.get_cmap('Blues')):

    fig = plt.figure()
    ax = fig.add_subplot(111)

    norm = visualization.ImageNormalize(S2D_spectra[exp_index], interval=visualization.ZScaleInterval())
    imshow = ax.imshow(S2D_spectra[exp_index], norm=norm, origin='lower', aspect='auto', cmap=cmap, interpolation='none')
    ax.set_xlabel('Pixel')
    ax.set_ylabel('order')
    fig.colorbar(imshow)
    fig.tight_layout()
    
    return fig, ax

def plot_single_order(S2D_spectra, order_index, cmap = matplotlib.cm.get_cmap('Blues')):
    
    fig = plt.figure()
    ax = fig.add_subplot(111)

    norm = visualization.ImageNormalize(S2D_spectra[:,order_index], interval=visualization.ZScaleInterval())
    imshow = ax.imshow(S2D_spectra[:,order_index], norm=norm, origin='lower', aspect='auto', cmap=cmap, interpolation='none')
    ax.set_xlabel('Pixel')
    ax.set_ylabel('Exposure')
    fig.colorbar(imshow)
    fig.tight_layout()
    
    return fig, ax

# %%
fig_exp, ax_exp = plot_single_exposure(S2D_spectra, exp_index=11)
plt.show()

# %% [markdown]
# We see that the 2 CCDs have different useful pixel numbers.

# %%
fig_order, ax_order = plot_single_order(S2D_spectra, order_index=130)
plt.show()

# %%
for w,s in zip(S2D_wavelengths_vacuum_bary[10], S2D_spectra[10]):
    plt.plot(w, s)
    
plt.ylim(0, 6000)
plt.xlim(4000, 4200)
plt.show()

# %% [markdown]
# ### Color-correction

# %% [markdown]
# Make the shape of the spectra consistent throughout the orders. This is not super-critical, and for the purpose of this tutorial I leave it out.

# %% [markdown]
# ### Removal of stellar lines

# %% [markdown]
# First, we create a common wavelength grid which on which we will provide the final spectra.

# %%
#
# Read BERV
#

BERVs = []
for hdu in hdus_S2D:
    BERVs.append(hdu[0].header['ESO QC BERV'])

#
# Calculate the laboratory vacuum wavelength solution, which we will use as a fixed, common grid throughout the analysis.
#

S2D_wavelengths_vacuum_laboratory = []

# The pipeline provides the wavelength array already shifted in the barycentric rest frame, so we shift it back.

from astropy.constants import c
c = (c.to('km s-1')).value

for n in range(len(S2D_wavelengths_vacuum_bary)):
    S2D_wavelengths_vacuum_laboratory.append(S2D_wavelengths_vacuum_bary[n] - S2D_wavelengths_vacuum_bary[n]*BERVs[n]/c)
S2D_wavelengths_vacuum_laboratory = np.array(S2D_wavelengths_vacuum_laboratory)

# %% [markdown]
# Now, we have to consider that the star is moving around the center of mass of the system. Thus, rather than calculating the spectra in the barycentric rest frame, we need to move to a system where the star is stationary.
#
# To do that, we need to know which planetary phases we are sampling, and calculate the corresponding stellar shift. In the process, we also calculate and store the planet phases and the planet velocitie which we will use in the following.
#
# We need to take care of the time conversions: the known ephemerid is given in BJD TDB, so we need to convert our exposure times to that same time scale and format. We use astropy for that. To do so, we calculate the BJD TDB time of every exposure.

# %%
from astropy import time
from astropy.coordinates import SkyCoord, EarthLocation

target_coordinates = SkyCoord.from_name(target_name)
site = EarthLocation.of_site('paranal')

time_observations = []

for hdu in hdus_S2D:
    exp_start=hdu[0].header['MJD-OBS']
    exp_dur=hdu[0].header['EXPTIME']
    time_observations.append(exp_start + exp_dur/(60.*60.*24.))

time_observations=time.Time(np.array(time_observations), format='mjd', scale='utc', location=site)

# We compute the time travel difference to the barycenter of the Solar System
dt_bary = time_observations.light_travel_time(target_coordinates)

# For the barycentric times, which are of our interest, the correct scale is TDB. (https://docs.astropy.org/en/stable/time/index.html#barycentric-and-heliocentric-light-travel-time-corrections).
bjd_time_observations = time_observations.tdb + dt_bary

# %% [markdown]
# Now, we calculate the planet phases, the planet velocities and the stellar velocities.

# %%
T0 =   2457273.4191 # BJD TDB; https://ui.adsabs.harvard.edu/abs/2022ApJS..258...40K/abstract
P_days = 1.8098806
r_AU = 0.0330

phases = ((bjd_time_observations.jd-T0)/P_days)%1
phases = np.where(phases < 0.5, 1+phases, phases) # To have them as a monotic sequence

r_km = r_AU*1.496e8
P_sec = P_days*24.*60.*60.
v_max = 2*np.pi*r_km/P_sec
planetary_velocities_during_transit = v_max*np.sin(phases*2.*np.pi)

k_star = 0.1193 # km/s
stellar_phases = 0.5+phases # Change the sign of the RV for the star.
stellar_velocities_during_transit = k_star*np.sin(stellar_phases*2.*np.pi)

# %% [markdown]
# Finally, we calculate the shift in wavelength in a rest frame which is stationary with respect to the star.
# $$\lambda_\mathrm{emit} = \lambda_\mathrm{obs} / (1 + v_\mathrm{emit}/c)\sim\lambda_\mathrm{obs}\cdot (1 - v_\mathrm{emit}/c)$$

# %%
S2D_wavelengths_vacuum_bary_stationary_star = []

for n in range(len(S2D_wavelengths_vacuum_bary)):
    S2D_wavelengths_vacuum_bary_stationary_star.append(S2D_wavelengths_vacuum_bary[n] - S2D_wavelengths_vacuum_bary[n]*stellar_velocities_during_transit[n]/c)
S2D_wavelengths_vacuum_bary_stationary_star = np.array(S2D_wavelengths_vacuum_bary_stationary_star)

# %% [markdown]
# We now move the spectra to the reference frame which co-moves with the star. The star does not move in this reference frame, thus it's best removed here.
#
# Practically, we express these shifted spectra onto the commong wavelength grid (S2D_wavelengths_vacuum_laboratory), to be able to work with them as a time-series.

# %%
S2D_spectra_stellar_rest_frame = []
for n in range(len(S2D_spectra)):
    S2D_spectra_stellar_rest_frame.append([np.interp(w, wn, s) for w, wn, s in zip(S2D_wavelengths_vacuum_laboratory[n], S2D_wavelengths_vacuum_bary_stationary_star[n], S2D_spectra[n])])

# %% [markdown]
# You may have noticed that adjacent orders do not "match". That is becasue the units we have been working on is "total photoelectrons received during the exposure time". In this specific pipeline we could work in photoelectrons, but I think for some cases it may be better to work in units of energy which is also more closely related to flux (flux = energy per unit time, area, solid angle). So let's calcuate howmuch energy has been deposited in every single pixel.
#
# For each pixel, we have to multiply by the total number of photons that hit it by the energy carreid by that photon. This is $h\nu$ or $\hbar/\lambda$. We neglect the constants, because we will normalize everything anyways. Note that we are assuming a single energy for all photoeleectrons falling on one pixel. You can verify yourself that this is a good approximation.

# %%
wave_bins = []

for n,w in enumerate(S2D_wavelengths_vacuum_laboratory[0]):
    
    #Compute the symmetric bins that cover the entire axis of wavelegths for a given set of wavelengths where the spectrum is known.
    #First bin extrapolated as identical to the second, and last bin to the previous.
    
    wave_bins.append([])
    wave_bins[n] = [ [(w[i-1] + w[i])/2.,(w[i] + w[i+1])/2.] for i in range(1,len(w)-1)]
    wave_bins[n].insert(0, [w[0] - (w[1] - w[0])/2., w[0] + (w[1] - w[0])/2. ])
    wave_bins[n].append([w[-1] - (w[-1] - w[-2])/2., w[-1] + (w[-1] - w[-2])/2. ])

wave_bins = np.array(wave_bins)
    
S2D_spectra_stellar_rest_frame = S2D_spectra_stellar_rest_frame/np.diff(wave_bins, axis=2)[:,:,0][None,:] # Now this is unit of total energy deposited in the pixel during the exposure time

# %% [markdown]
# We can now verify that the downwar slope is gone, and each order naturally goes into the next one. Spectral lines now have the correct shape. The "jumps" you can still see are not real, and are instead due to the high noise found in the blue part of each order because of the blaze function.

# %%
for w,s in zip(S2D_wavelengths_vacuum_laboratory[10], S2D_spectra_stellar_rest_frame[10]):
    plt.plot(w, s)
    
np.save('S2D_spectra_stellar_rest_frame_with_star_included', S2D_spectra_stellar_rest_frame)
    
plt.ylim(1.e3, 5.e5)
plt.xlim(4000, 4200)
plt.show()

# %% [markdown]
# Our spectra are finally ready to remove the stellar lines. To do that, we use the same trick employed by PCA. Since telluric correction is much less important in the optical, we ignore that, and we can use a much simpler method. We simply build a master spectrum by taking a median in time of all the spectra, while we are in the star rest frame. The planet is moving, and it is not removed. Tellurics are not removed because they vary in time.
#
# However, right now, the trick would not work because we have variable throughput during the night, and the median would give nonsense results. So let's first bring all the spectra to a common level. We do this order by order, because we did not perform a color-correction. I do this order by order also when I do perform the color-correction, because I think this is the most reliable way (color-correction still corrects inter-order continuum variations).

# %%
# Take the two central quartes of each order
i1 = 2277
i2=6833

S2D_spectra_stellar_rest_frame_rescaled = []
for s in S2D_spectra_stellar_rest_frame:
    S2D_spectra_stellar_rest_frame_rescaled.append(s/np.average(s[:,i1:i2], axis=1)[:,None])
S2D_spectra_stellar_rest_frame_rescaled = np.array(S2D_spectra_stellar_rest_frame_rescaled)

    
print(np.shape(S2D_spectra_stellar_rest_frame))
print(np.shape(S2D_spectra_stellar_rest_frame_rescaled))
    
fig_order, ax_order = plot_single_order(S2D_spectra_stellar_rest_frame, order_index=130)
fig_order_rescaled, ax_order_rescaled = plot_single_order(S2D_spectra_stellar_rest_frame_rescaled, order_index=130)
# Out:
# (70, 170, 9111)
# (70, 170, 9111)

# %% [markdown]
# Now that the spectra are **rescaled** we can  **normalize** them by a master stellar spectrum (which contains some tellurics as well).

# %%
S2D_spectra_stellar_rest_frame_normalized = []
median_S2D_spectra_stellar_rest_frame_rescaled = np.median(S2D_spectra_stellar_rest_frame_rescaled, axis=0)
for s in S2D_spectra_stellar_rest_frame_rescaled:
    S2D_spectra_stellar_rest_frame_normalized.append(s/median_S2D_spectra_stellar_rest_frame_rescaled)
S2D_spectra_stellar_rest_frame_normalized = np.array(S2D_spectra_stellar_rest_frame_normalized)

fig_order_normalized, ax_order_normalized = plot_single_order(S2D_spectra_stellar_rest_frame_normalized, order_index=131)

# Plot master ontop of one exposure
plt.figure()
for o in range(170):
    plt.plot(S2D_wavelengths_vacuum_laboratory[50, o], S2D_spectra_stellar_rest_frame_rescaled[50, o], 'k', S2D_wavelengths_vacuum_laboratory[50, o], median_S2D_spectra_stellar_rest_frame_rescaled[o], 'r')

plt.xlim(4100, 4110)
plt.ylim(-0.1, 1.5)
# Out:
# <ipython-input-29-163d654683a9>:4: RuntimeWarning: divide by zero encountered in true_divide
#   S2D_spectra_stellar_rest_frame_normalized.append(s/median_S2D_spectra_stellar_rest_frame_rescaled)
# <ipython-input-29-163d654683a9>:4: RuntimeWarning: invalid value encountered in true_divide
#   S2D_spectra_stellar_rest_frame_normalized.append(s/median_S2D_spectra_stellar_rest_frame_rescaled)
# (-0.1, 1.5)

# %% [markdown]
# Remember that the first orders have less pixels? When we divide by zero we get a warning. If we are not extremely careful, our cross-correlations and likelihoods will make no sense. I thus prefer to set nans to zeros, which is the null value for the binary mask cross-correlations (if you use other methods, you may need to set it to one, or other values

# %%
S2D_spectra_stellar_rest_frame_normalized = np.nan_to_num(S2D_spectra_stellar_rest_frame_normalized)

# Plot final spectra
plt.figure()
for o in range(170):
    plt.plot(S2D_wavelengths_vacuum_laboratory[50, o], S2D_spectra_stellar_rest_frame_normalized[50, o], 'k')

plt.xlim(4100, 4200)
plt.ylim(-0.1, 1.5)

np.save('S2D_wavelengths_vacuum_laboratory', S2D_wavelengths_vacuum_laboratory)
np.save('S2D_spectra_barycentric_normalized', S2D_spectra_stellar_rest_frame_normalized)

# %% [markdown]
# And we are ready to cross-correlate! Of course, you should be aware that we have not corrected for tellurics. While this can be fine for the bluest orders, for example if you focus on neutral iron, or it could be fine for a quick look, you probably want to implement a telluric correction or at least mask out the contaminated regions before proceeding.
#
# Also, note how the singal to noise is strongly varying with wavelength. This is something that we need to consider when cross-correlating with yout favorite method. Did you already guess why the noise in the blue parts of the order is so high?

# %%
import glob
data_files_A_blaze = glob.glob(input_data_directory + '*BLAZE_A_*')
blaze_profiles = fits.open(data_files_A_blaze[0])[1].data

for w, b in zip(S2D_wavelengths_vacuum_laboratory[0], blaze_profiles):
    plt.plot(w, b, 'k')
    
plt.xlim(4100, 4200)
# Out:
# (4100.0, 4200.0)

# %% [markdown]
# Typically, two more operations can be performed on data, which will improve the significance. ESPRESSO is a good instruments, thus the improvement is only marginal. I do not include them here. In the full pipeline, I will implement those methods.
# 1. High-pass filtering to remove smooth variations (imperfect blaze correction or color-correction, ...)
# 2. Removal of outliers (cosmic rays etc).
# In ESPRESSO, the first step is important for publishing since there is an effect called "wiggles", which are low frequency oscillations observed ontop of the specrta, with phase change typically occurring at half of the night.
